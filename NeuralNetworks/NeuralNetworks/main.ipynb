# %%
from network import *
import torchvision
from numpy import eye, int32, float32, array

# %%
X = array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])

Y = array([
    [1,0],
    [0,1],
    [0,1],
    [1,0]
])

# %%
model = Network(
    layerSizes=[2,4,2],
    activations=["relu","softmax"],
    lossName="crossentropy"
)

print(model.Predict(X))

model.Train(X, Y, learningRate=0.1, epochs=1000, batchSize=4)

print(model.Predict(X))
# Out:
# [0 0 0 0]
# Epoch 1: Loss=0.2327  Test Accuracy=nan%
# Epoch 2: Loss=0.2246  Test Accuracy=nan%
# Epoch 3: Loss=0.2175  Test Accuracy=nan%
# Epoch 4: Loss=0.2113  Test Accuracy=nan%
# Epoch 5: Loss=0.2058  Test Accuracy=nan%
# Epoch 6: Loss=0.2009  Test Accuracy=nan%
# Epoch 7: Loss=0.1966  Test Accuracy=nan%
# Epoch 8: Loss=0.1928  Test Accuracy=nan%
# Epoch 9: Loss=0.1893  Test Accuracy=nan%
# Epoch 10: Loss=0.1862  Test Accuracy=nan%
# Epoch 11: Loss=0.1833  Test Accuracy=nan%
# Epoch 12: Loss=0.1807  Test Accuracy=nan%
# Epoch 13: Loss=0.1783  Test Accuracy=nan%
# Epoch 14: Loss=0.1761  Test Accuracy=nan%
# Epoch 15: Loss=0.1741  Test Accuracy=nan%
# Epoch 16: Loss=0.1721  Test Accuracy=nan%
# Epoch 17: Loss=0.1704  Test Accuracy=nan%
# Epoch 18: Loss=0.1687  Test Accuracy=nan%
# Epoch 19: Loss=0.1671  Test Accuracy=nan%
# Epoch 20: Loss=0.1655  Test Accuracy=nan%
# Epoch 21: Loss=0.1641  Test Accuracy=nan%
# Epoch 22: Loss=0.1628  Test Accuracy=nan%
# ...
