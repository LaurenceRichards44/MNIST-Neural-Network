# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import OneHotEncoder
import numpy as np
from network import Network

# %%
data = load_iris()

X = data.data
y = data.target

encoder = OneHotEncoder(sparse_output=False)
Y = encoder.fit_transform(y.reshape(-1,1))

labels=["setosa","versicolor","virginica"]
print(labels)
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
model = Network(
    layerSizes=[4,16,16,3],
    activations=["relu","relu","softmax"],
    lossName="crossentropy",
)

model.Train(X, Y, learningRate=0.01, epochs=200, epochsPerPrint=10, batchSize=16, testSize=0.2, labels=labels)
# Out:
# Epoch 10    Loss=0.0371, Test Accuracy=100.00%
# Epoch 20    Loss=0.0304, Test Accuracy=100.00%
# Epoch 30    Loss=0.0265, Test Accuracy=100.00%
# Epoch 40    Loss=0.0267, Test Accuracy=100.00%
# Epoch 50    Loss=0.0166, Test Accuracy=100.00%
# Epoch 60    Loss=0.0150, Test Accuracy=100.00%
# Epoch 70    Loss=0.0150, Test Accuracy=100.00%
# Epoch 80    Loss=0.0121, Test Accuracy=100.00%
# Epoch 90    Loss=0.0126, Test Accuracy=100.00%
# Epoch 100   Loss=0.0100, Test Accuracy=100.00%
# Epoch 110   Loss=0.0096, Test Accuracy=100.00%
# Epoch 120   Loss=0.0148, Test Accuracy=100.00%
# Epoch 130   Loss=0.0105, Test Accuracy=100.00%
# Epoch 140   Loss=0.0108, Test Accuracy=100.00%
# Epoch 150   Loss=0.0084, Test Accuracy=100.00%
# Epoch 160   Loss=0.0076, Test Accuracy=100.00%
# Epoch 170   Loss=0.0079, Test Accuracy=100.00%
# Epoch 180   Loss=0.0082, Test Accuracy=100.00%
# Epoch 190   Loss=0.0083, Test Accuracy=100.00%
# Epoch 200   Loss=0.0070, Test Accuracy=100.00%

# %%
model.Summary()
# Out:
# Model Summary
# ==================================================
# Layer      Input → Output       Activation      Params
# --------------------------------------------------
# 0          4→16              ReLU            80
# 1          16→16              ReLU            272
# 2          16→3               Softmax         51
# --------------------------------------------------
# Total parameters: 403
# ==================================================

# %%
model.PlotLossAccuracy
# Out:
# <bound method Network.PlotLossAccuracy of <network.Network object at 0x000001BAC1004050>>
